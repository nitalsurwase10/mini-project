# %%
#list
list is mutable
to create []
maxium value store

# %%
l =[10,22,20,30,44,50]
l[1]=20 #  mutable nature =you can change value on your list
print(l)
# Out:
# [10, 20, 20, 30, 44, 50]

# %%
#traversing on list
a=[10,20,30,40,50]
for i in a:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
a=[10,20,30,40,50]
for i in range(0,len(a)):
    print(f"{i}:{a[i]}")
# Out:
# 0:10
# 1:20
# 2:30
# 3:40
# 4:50

# %%
#list method #
#1. append # is built in python list method that adds a single element to end of list
a =[10,20,40,50,60]
a.insert(2,30)   #insert at index
a.append("hello")
print(a)
# Out:
# [10, 20, 30, 40, 50, 60, 'hello']

# %%
#pop remove and return an element from a list
l =[10,20,30,40,55,60]
a=l.pop(4)
print(a)
# Out:
# 55

# %%
#3.remove remove first 1
l =[10,20,30,40,55,60]
print(l.remove(55))
print(l)
# Out:
# None
# [10, 20, 30, 40, 60]

# %%
#sort sort the list assingding order and  return none
l =[10,50,25,40,55,60,20]
l.sort(reverse =True)
print(l)
# Out:
# [60, 55, 50, 40, 25, 20, 10]

# %%
l=[3,-1,4,-5,9]
pos =[]
neg =[]
for i in l:
    if i>=0:
        pos.append(i)
    else:
        neg.append(i)
print(f"your positive element are {pos}")
print(f"your positive element are {ng}")

# %%
2.
l=[100,600,300,400,200,500,300]
largest =max(l)
print(f"largest number: {largest}")
print(l)
# Out:
# largest number: 600
# [100, 600, 300, 400, 200, 500, 300]

# %%
l=[100,600,300,400,200,70,500,300]
smallest = min(l)
print(f"smallest number: {smallest}")
print(l)
# Out:
# smallest number: 70
# [100, 600, 300, 400, 200, 70, 500, 300]

# %%
l=[100,600,300,400,200,500,300]
l = list(set(l))
print(l)
# Out:
# [100, 200, 300, 400, 500, 600]

# %%
l=[100,600,300,400,200,500,300]
new_list =[]
for i  in l:
    if i not in new_list:
        new_list.append(i)
print(new_list)
# Out:
# [100, 600, 300, 400, 200, 500]

# %%
l=[100,600,300,9,7,53,400,200,41,70,500,300]
even =[]
odd=[]
for i in l:
    if i%2==0:
        even.append(i)
    else:
        odd.append(i)
print("even number:",even ,end =")
print("odd number:",odd)
# Out:
# even number: [100, 600, 300, 400, 200, 70, 500, 300]
# odd number: [9, 7, 53, 41]

# %%
l=[100,600,300,400,200,500,300]
sum= 1
for i in l:
    sum =sum*i
print("sum :",sum)
# Out:
# sum : 216000000000000000

# %%
l=[100,600,300,400,200,500,300]
print(l.sort())
print(l)
# Out:
# None
# [100, 200, 300, 300, 400, 500, 600]

# %%
l=[100,600,300,400,200,500,300]
print(l.sort(reverse=True))
print(l)
# Out:
# None
# [600, 500, 400, 300, 300, 200, 100]

# %%
l=[100,600,300,400,200,500,300]
print(l.reverse())
print(l)
# Out:
# None
# [300, 500, 200, 400, 300, 600, 100]

# %%
l1=[100,600,300,400,200,500,300]
l2 =[700,800,900,200,4000]
marge =[]
for i in l1:
       marge.append(i)
for i in l2:
    marge.append(i)
print("marge",marge)
# Out:
# marge [100, 600, 300, 400, 200, 500, 300, 700, 800, 900, 200, 4000]

# %%
l=[100,600,300,400,200,500,300]
largest = max(l)
l.sort()
smallest = min(l)
print("largest number:",largest)
print("second largest number:", l[-2])
print("smallest number:",smallest)
print(l)
# Out:
# largest number: 600
# second largest number: 500
# smallest number: 100
# [100, 200, 300, 300, 400, 500, 600]

# %%
list 
 list is a collection of multiple value stored in single varible
list is mutable
list is ordered changeble and allow duplicate value 

extend and append 
extend 
multiple value add 
append 
one element add

# %%
#2. how to create a list 
n = [20,30,40,50,10,70,30,40,50]
print(n.append(100))
print(n.remove(10))
print(len(n))
print(n)
print(a.count(50))
print(type(n))
# Out:
# None
# None
# 9
# [20, 30, 40, 50, 70, 30, 40, 50, 100]
# 1
# <class 'list'>

# %%
a =[20,30,49,50,60]
print(a[0])
print(max(a))
print(min(a))
# Out:
# 20
# 60
# 20

# %%
movie =["thral tr mg","lagana nantar hoil ch pram","aai kuthe ky karte","gharo ghari maticha chuli","pathrakin"]    
movie.append("lapndav")
movie.remove("aai kuthe ky karte")
movie.insert(2,"rang mazay vegala")
print(len(movie))
print(movie)
# Out:
# 6
# ['thral tr mg', 'lagana nantar hoil ch pram', 'rang mazay vegala', 'gharo ghari maticha chuli', 'pathrakin', 'lapndav']

# %%
name =["nital","sanika","gangu","shweta","janvi"]
name.append("snehal")
name.remove("gangu")
name.insert(1,"priya")
print(len(name))
print(name)
# Out:
# 6
# ['nital', 'priya', 'sanika', 'shweta', 'janvi', 'snehal']

# %%
marks =[65,78,56,90,55,99,100,35,55,90,55]
print(max(marks))
print(min(marks))
print(marks.count(55))
marks.sort()
marks.reverse()
print(marks)
# Out:
# 100
# 35
# 3
# [100, 99, 90, 90, 78, 65, 56, 55, 55, 55, 35]

# %%
a = [30,20,30,10,40,20,30,50,30,40]
print(a.count(30))
print(a[3])
print(a)
# Out:
# 4
# 10
# [30, 20, 30, 10, 40, 20, 30, 50, 30, 40]
